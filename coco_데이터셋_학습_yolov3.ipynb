# %% [markdown]
# ### Ultralytics Yolo v3 설치

# %%
# Ultralytics Yolo v3 모델 다운로드
# !git clone https://github.com/ultralytics/yolov3
# !cd yolov3;pip install -qr requirements.txt
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 12088, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 12088 (delta 22), reused 15 (delta 15), pack-reused 12034 (from 3)
# Receiving objects: 100% (12088/12088), 10.65 MiB | 20.80 MiB/s, done.
# Resolving deltas: 100% (8198/8198), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 45.3 MB/s eta 0:00:00

# %%
# 설정 확인
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.5.1+cu124 (Tesla T4)

# %%
# 학습 실행
# runs/train/exp 아래 각종 결과 저장
# %cd yolov3
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3.pt --nosave
# Out:
# [Errno 2] No such file or directory: 'yolov3'
# /content/yolov3
# Traceback (most recent call last):
#   File "/content/yolov3/train.py", line 34, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2475, in <module>
#     from torch import (
#   File "/usr/local/lib/python3.11/dist-packages/torch/export/__init__.py", line 28, in <module>
#     from torch.fx.passes.infra.pass_base import PassResult
#   File "/usr/local/lib/python3.11/dist-packages/torch/fx/passes/__init__.py", line 1, in <module>
#     from . import graph_drawer
#   File "/usr/local/lib/python3.11/dist-packages/torch/fx/passes/graph_drawer.py", line 17, in <module>
#     import pydot
#   File "/usr/local/lib/python3.11/dist-packages/pydot/__init__.py", line 19, in <module>
#     from pydot.core import *  # noqa: F403, E402
#     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pydot/core.py", line 17, in <module>
#     from pydot._vendor import tempfile
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1069, in get_code
#   File "<frozen importlib._bootstrap_external>", line 729, in _compile_bytecode
# KeyboardInterrupt
# ^C
